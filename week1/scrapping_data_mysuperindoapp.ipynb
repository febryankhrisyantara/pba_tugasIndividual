# %% [markdown]
# # Instalasi dan Import Library

# %%
# !pip install google_play_scraper pandas numpy
# Out:
# Requirement already satisfied: google_play_scraper in c:\users\ryanf\appdata\local\programs\python\python312\lib\site-packages (1.2.7)
# Requirement already satisfied: pandas in c:\users\ryanf\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy in c:\users\ryanf\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ryanf\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ryanf\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ryanf\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\ryanf\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from google_play_scraper import reviews, Sort

# %% [markdown]
# # Data Collection (Scraping)
#
# Mengambil 50.000 ulasan terbaru aplikasi MySuperindo dari Google Play Store.

# %%
app_id = 'id.co.superindo.mysuperindo'

print(f"Mulai mengambil sampel data ulasan {app_id}...")
app_reviews, _ = reviews(
    app_id,
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=50000
)

df_reviews = pd.DataFrame(app_reviews)
print(f"Total ulasan terkumpul: {df_reviews.shape[0]} baris")

def mask_username(username):
    if pd.isna(username): return username
    username = str(username)
    if len(username) <= 4: return "*" * len(username)
    return username[:2] + "*" * (len(username)-4) + username[-2:]

df_reviews['userName'] = df_reviews['userName'].apply(mask_username)
df_reviews.to_csv("mysuperindo_reviews_raw.csv", index=False)
print("Data berhasil disimpan ke 'mysuperindo_reviews_raw.csv'")
df_reviews.head()
# Out:
# Mulai mengambil sampel data ulasan id.co.superindo.mysuperindo...
# Total ulasan terkumpul: 8765 baris
# Data berhasil disimpan ke 'mysuperindo_reviews_raw.csv'
#                                reviewId         userName  \
# 0  25903600-9941-41cf-aaa0-ceaeec5845bd  Pe***********le
# 1  f7dcaf94-368f-4ac9-9933-4b8fdedf9979  Pe***********le
# 2  90e1d555-e23f-4b18-8f1e-24160ebb56e6  Pe***********le
# 3  2c9cc04b-ec34-4db2-b9ba-5100646bbdd9  Pe***********le
# 4  72264776-7d92-4ede-a5f6-b7d6be6b45b5  Pe***********le
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0            aplikasi udh 2 hri error gada perbaikan      1              0
# 1  tolong dipermudah proses pembatalan pesanan, i...      3              0
# 2  saya di Kediri pelayanan lama aplikasi eror ti...      1              0
# 3                    belanja mudah, murah dan nyaman      5              0
# 4  belanja d superindo sangat memuaskan. harga ny...      5              0
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0            21.00.000 2026-03-29 10:08:18         None       NaT  21.00.000
# 1            21.00.000 2026-03-29 09:24:51         None       NaT  21.00.000
# 2            21.00.000 2026-03-28 20:02:26         None       NaT  21.00.000
# 3            21.00.000 2026-03-28 13:24:39         None       NaT  21.00.000
# 4            21.00.000 2026-03-26 05:12:50         None       NaT  21.00.000
